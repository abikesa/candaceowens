# %% [markdown]
# (orient)=
# # Orient
#
# The rise and fall of Sam Bankman-Fried and his ventures, such as FTX and Alameda Research, illuminate a saga of entropy and optimization, risk and reward, and the shifting tides of connotation and morality in modern markets. Founded in Berkeley and strategically set up in Hong Kong, FTX epitomized a system where entropy—mirroring the chaotic unpredictability of dice rolls and roulette spins—met the gravitational pull of capital and arbitrage. Within this universe, the gates were open to all, suggesting a utopia of perfect information and fixed odds. Yet, the illusion of fairness in this system obscured deeper layers of asymmetry and volatility, echoing the inherent instability of the cosmos itself.
#
# > *Many ex-poker players started trading crypto during COVID, beginning of bullmarket. Enter FTX*
# -- Bloomberg
#
# Patterns emerged as Bankman-Fried's ventures wove an intricate tapestry of risk, problem-solving, and mathematical finesse honed at MIT. In this sphere, the game shifted from egalitarian randomness to an environment of asymmetric information, where access to the "key" determined the odds. Poker replaced roulette, blockchain replaced static ledgers, and speculation took precedence over certainty. The narrative became one of obsession with trust and its monetization, as the openness and transparency heralded by decentralization were ironically sold as commodities, creating a paradox that mirrors the untrusted dynamics of systems like horse racing. Here, only those with access to the key knew the truth, while others gambled in ignorance.
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/3QpdU9LS540?start=780" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
#
# ```{figure} ../figures/blanche.*
# ---
# width: 1
# height: 1
# ---
# _The Wabbit_? Let's think of the rabbit hole as a massive combinatorial search space. Is it cooperative, iterative, or adversarial? Let's clarify one thing: "Kill the Wabbit" is outright adversarial. So our discussion is about "Following the Wabbit!." We are a bunch of 25 year olds, we don't know what a bitcoin is, but we are trading it.
# ```
#
# Bankman-Fried’s accumulation of capital, initially derived from family wealth and later augmented by the markets, symbolized an era of speculative entrants and exits, where the odds remained uncertain, and the stakes were perpetually high. This connotation resonated in the culture of high-stakes horse racing, where participants rely on intuition, strategy, and the sheer force of chance. Yet, as the focus shifted to the intersection of US-Japan arbitrage in crypto pricing, a new dynamic emerged: the weaponization, tokenization, and monopolization of access to financial tools. Stable-diffusion algorithms and conditional odds became instruments of control, amplifying the delusions of monopolistic power within structures like FTX and its shadowy twin, Alameda Research.
#
# The tendency toward innocuous branding—epitomized by the disarmingly bland "Alameda Research"—disguised a deeper ethos of optimization. Beneath the surface, these organizations exploited volatility, uncertainty, freedom, and stability, weaving a narrative that oscillated between Victorian morality and the aesthetic absurdity of the Coen Brothers. This duality—between teleological aims and Nietzschean eternal return—revealed a system driven less by ethics and more by a relentless pursuit of advantage, reflecting the inherent contradictions of modern capitalism.
#
# Ultimately, the network Bankman-Fried constructed, whether viewed through the lens of neural architecture or economic stratagem, serves as a fractal reflection of the world he sought to dominate. It is a universe of perception and agency, shaped by immutable laws of nature and society, yet defined by the interplay of open and closed systems. The collapse of FTX and the unraveling of its carefully curated image offer a stark reminder of the fragility of systems predicated on trust without transparency. As the dust settles, we are left with a poignant conundrum: Was it a failure of morality, a miscalculation of risk, or simply an inevitable consequence of the entropy that defines human endeavor?

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# Define the neural network fractal
def define_layers():
    return {
        'World': ['Cosmos-Entropy', 'Planet-Tempered', 'Life-Needs', 'Ecosystem-Costs', 'Generative-Means', 'Cartel-Ends', ], ## Cosmos, Planet
        'Perception': ['Perception-Ledger'], # Life
        'Agency': ['Open-Nomiddleman', 'Closed-Trusted'], # Ecosystem (Beyond Principal-Agent-Other)
        'Generative': ['Ratio-Weaponized', 'Competition-Tokenized', 'Odds-Monopolized'], # Generative
        'Physical': ['Volatile-Distributed', 'Unknown-Players',  'Freedom-Crypto', 'Known-Transactions', 'Stable-Central'] # Physical
    }

# Assign colors to nodes
def assign_colors():
    color_map = {
        'yellow': ['Perception-Ledger'],
        'paleturquoise': ['Cartel-Ends', 'Closed-Trusted', 'Odds-Monopolized', 'Stable-Central'],
        'lightgreen': ['Generative-Means', 'Competition-Tokenized', 'Known-Transactions', 'Freedom-Crypto', 'Unknown-Players'],
        'lightsalmon': [
            'Life-Needs', 'Ecosystem-Costs', 'Open-Nomiddleman', # Ecosystem = Red Queen = Prometheus = Sacrifice
            'Ratio-Weaponized', 'Volatile-Distributed'
        ],
    }
    return {node: color for color, nodes in color_map.items() for node in nodes}

# Calculate positions for nodes
def calculate_positions(layer, x_offset):
    y_positions = np.linspace(-len(layer) / 2, len(layer) / 2, len(layer))
    return [(x_offset, y) for y in y_positions]

# Create and visualize the neural network graph
def visualize_nn():
    layers = define_layers()
    colors = assign_colors()
    G = nx.DiGraph()
    pos = {}
    node_colors = []

    # Add nodes and assign positions
    for i, (layer_name, nodes) in enumerate(layers.items()):
        positions = calculate_positions(nodes, x_offset=i * 2)
        for node, position in zip(nodes, positions):
            G.add_node(node, layer=layer_name)
            pos[node] = position
            node_colors.append(colors.get(node, 'lightgray'))  # Default color fallback

    # Add edges (automated for consecutive layers)
    layer_names = list(layers.keys())
    for i in range(len(layer_names) - 1):
        source_layer, target_layer = layer_names[i], layer_names[i + 1]
        for source in layers[source_layer]:
            for target in layers[target_layer]:
                G.add_edge(source, target)

    # Draw the graph
    plt.figure(figsize=(12, 8))
    nx.draw(
        G, pos, with_labels=True, node_color=node_colors, edge_color='gray',
        node_size=3000, font_size=9, connectionstyle="arc3,rad=0.2"
    )
    plt.title("Sam Bankman-Fried", fontsize=15)
    plt.show()

# Run the visualization
visualize_nn()

# %% [markdown]
# ```{figure} ../../figures/blanche.*
# ---
# width: 1
# height: 1
# ---
# IT’S A REALLY, surprisingly user-friendly experience,” says Stephen Askins, a shipping lawyer, of his interactions with the Houthis, the militia that has been attacking commercial ships in the Red Sea for more than a year. “You write to them, respectfully. They write back, respectfully, and wish you a happy passage.” Source: [Economist](https://www.economist.com/interactive/international/2025/01/18/inside-the-houthis-moneymaking-machine)
# ```
#
# <Details>
#     <Summary></Summary>
#
# 1. Entropy, Gravity: Founded in Berkeley & setup in Hongkong
#    - Gate: everyone is within the gates, perfect information, fixed odds
#    - Coin toss, Dice roll, Roulette spin
# 2. Patterns: Obsessed with risk, solving puzzles, Maths from MIT
#    - Key: only you are in and others speculate, asymmetric information, wild odds
#    - Poker, Blockchain, Untrusted (Sam Blankman-Fried "sold" trust instead of openness)
# 3. Connotation: Got kapital from family & later market
#    - Entrants: with their exits and entrances, uncertain odds
#    - Horse racing
# 4. Interaction: US-Japan arbitrage on crypto pricing
#    - Stable-Diffusion: weaponized, tokenized, monopolized access-to-key, conditional odds
#    - Red Queen, Exchanges, FTX (nested within Alameda; same people; monopoly-delusion)
# 5. Tendency: Innocuous name: Alameda Research vs. FTX
#    - Optimization: volatility, uncertainty, freedom, certainty, stability
#    - Victorian vs. Coen Brothers, Morality vs. Aesthetics, Teleology vs. Eternal Return
#
#
# </Details>
