# %% [markdown]
# (orient)=
# # Orient
#
# ## Version 1
# The meteoric rise and precipitous collapse of Sam Bankman-Fried's FTX empire is a case study in entropy masquerading as optimization—a gravitational inevitability cloaked in the veneer of progress. From its genesis in Berkeley, through its transient stops in Hong Kong and the Bahamas, and its eventual unspooling under U.S. jurisdiction, FTX promised a world where everyone was "within the gates." The pitch? Perfect information, fixed odds, and a bespoke regulatory environment. The reality? A loaded dice game of asymmetric information and speculative frenzy, dressed up as fairness.
#
# > *"Many ex-poker players started trading crypto during COVID, at the start of the bull market. Enter FTX."*
# – *Bloomberg*
#
# Bankman-Fried’s brilliance lay in his ability to frame volatility as control, leveraging his MIT-honed mathematical rigor to craft an audacious vision. FTX was never just about decentralization—it was about power. In a paradoxical twist, Bankman-Fried weaponized trust as his currency, replacing blockchain’s promise of transparency with a theater of confidence and opacity. The "fairness" he sold was never egalitarian; it was a poker table where only those holding the "key" (FTTs) knew the odds, leaving others to gamble blindly. In this environment, chaos wasn’t a bug—it was the system’s primary feature.
#
# ## From Berkeley to Bahamas: A Game of Entrants and Exits
#
# FTX’s ascension relied on a meticulous choreography of entrants and exits. Beginning with familial capital, Bankman-Fried layered legitimacy through market validations and strategic lobbying in Washington, D.C., hinting at the promise of unlocking Wall Street’s deepest coffers. The stage was set, and the props were tokens—tangible enough to inspire trust, intangible enough to evade scrutiny. Like a high-stakes horse race, FTX thrived on uncertain odds and the illusion of control, a meta-gamble that elevated speculation to an art form.
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/3QpdU9LS540?start=780" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
#
# ```{figure} ../figures/blanche.*
# ---
# width: 1
# height: 1
# ---
# This was a fork in the road for human civilization. Our dear planet earth now becomes just but an optional resource on which we jostle for resources. By expanding to Mars, the jostle reduces for perhaps a couple of centuries of millenia. There need to be things that inspire you. Things that make you glad to wake up in the morning and say "I'm looking forward to the future." And until then, we have gym and coffee -- or perhaps gin & juice. We are going to have a golden age. One of the American values that I love is optimism. We are going to make the future good.
# ```
#
#
#
# The cracks in this façade began to show in the interplay between FTX and its shadowy sibling, Alameda Research. While U.S.-Japan arbitrage on crypto pricing offered a tantalizing glimpse of efficiency, the reality was less sophisticated. FTX and Alameda functioned as a closed loop of tokenized promises and circular credit—a house of cards where stability was an illusion. Alameda’s dependence on FTT as collateral rendered it an Achilles’ heel; when lenders began testing the waters of suspicion, the system’s precarious balance tipped.
#
# ## The Red Queen Gambit: Monopoly as Delusion
#
# At its core, FTX’s collapse mirrors the Red Queen principle: a relentless race to maintain power while the foundation erodes. Bankman-Fried styled himself as the "crypto J.P. Morgan," a savior bailing out failing ventures while concealing his empire’s fragility. Yet, this bravado masked the monopoly delusion—a stable-diffusion dynamic where access to the "key" was weaponized and monopolized, ensuring that power remained concentrated even as the system weakened.
#
# Bankman-Fried’s refusal to pivot into survival mode sealed his fate. Alameda’s balance sheet, propped up by self-referential tokens, could not withstand a run on FTX. The empire, built on tokens of trust conjured from thin air, succumbed to the forces of entropy it had sought to dominate.
#
# ## A Tale of Tokens, Resources, and Odds
#
# The narrative of FTX encapsulates the paradox of crypto itself. Bitcoin offers fixed odds and transparency—a coin toss where the rules are clear. In contrast, FTX thrived on volatility conjured from nothing, a roulette spin where the house always won. As the ecosystem crumbled, it became evident that the dice were never fair.
#
# ### Structure of Collapse:
#
# 1. **Entropy and Gravity**: From Berkeley to Hong Kong to the Bahamas to the U.S., FTX’s trajectory reflected a gravitational pull toward collapse, dressed as optimization.
#    - **The Gate**: Promised inclusion, but with fixed odds favoring the insiders.
#    - **Bespoke Regulation**: Coin toss, dice roll, and roulette spin—always favoring the house.
#
# 2. **Risk and Obsession**: Bankman-Fried’s fixation on puzzles and mathematical rigor weaponized trust over transparency.
#    - **The Key**: Asymmetric information ensured only insiders held the odds, turning trust into the ultimate currency.
#    - **Poker Table**: A stage where blockchain’s decentralization was replaced by untrusted opacity.
#
# 3. **Entrants and Exits**: Early capital came from familial trust; legitimacy was built on regulatory whispers in D.C.
#    - **Horse Racing**: Strategic bets on uncertain odds, with Wall Street access as the ultimate prize.
#
# 4. **Shadow Dynamics**: The interaction between FTX and Alameda revealed a fragile system of monopolized access and conditional odds.
#    - **Stable Diffusion**: Tokenized control, nested monopolies, and the illusion of stability.
#
# 5. **Victorian Morality Meets Coen Brothers Absurdity**: A system trapped between optimization and collapse.
#    - **Teleology vs. Eternal Return**: The promises of progress 🕊️ undone by the gravitational 🌍  pull of entropy.
#
# ## Conclusion: The Aesthetic of Collapse 🕊️
#
# The collapse of FTX serves as both a cautionary tale and a mirror of crypto’s paradoxes. What began as an optimization of volatility ended in a spiral of entropy. Bankman-Fried, the self-styled savior, became the architect of his own undoing. His empire’s rise and fall weren’t just about tokens and odds—they were a study in the delicate balance between trust, power, and the gravitational pull of chaos.
#
# > "To demand moral purpose from the artist is to make him ruin his work," Goethe wrote. Bankman-Fried demanded the purpose of optimization from a system that thrives on volatility, and in doing so, unraveled its delicate artifice. The Victorian in us demands a moral; the Coen Brothers would offer only a wry shrug. Perhaps both are correct.
#
# ## Version 2
#
# The rise and collapse of FTX, under Sam Bankman-Fried, is a microcosm of modernity’s tenuous dance between optimization and entropy. It embodies the paradoxical interplay of progress cloaked in the chaos of high-stakes experimentation. From its origins in Berkeley’s intellectual crucible, to its shadowy iterations in Hong Kong and the Bahamas, and ultimately its implosion under U.S. regulatory scrutiny, FTX was less a triumph of decentralized vision than an elaborate façade of power disguised as trust. The rhetoric of “perfect information” and “inclusive gates” gave way to a system where control was concentrated in the hands of those who held the symbolic keys—tokens such as FTT—ensuring that power was never decentralized but monopolized under the guise of fairness.
#
# Bankman-Fried’s genius lay in reframing volatility as control. Armed with MIT-caliber mathematical rigor, he conjured an ecosystem where risk was commodified and leveraged into speculative wealth. Yet, the architecture of FTX was a game of mirrors: it offered the illusion of stability through intricate layers of self-referential credit and opaque transactions, all while perpetuating chaos as its core feature. The brilliance of his pitch was its paradox: blockchain transparency was replaced by a theater of confidence, where belief in the system’s infallibility was weaponized as its primary currency.
#
# FTX’s meteoric rise depended on a delicate choreography of entrants and exits. Familial trust seeded its foundations, while strategic lobbying in Washington, D.C., laid the groundwork for institutional legitimacy. This was a world where tokens served as both the bait and the switch—appearing tangible enough to inspire trust, yet elusive enough to evade scrutiny. Bankman-Fried’s vision was nothing short of a high-stakes horse race, where the odds were deliberately obscured and the game perpetually recalibrated to favor the house.
#
# The cracks in FTX’s empire began to show as its incestuous relationship with Alameda Research unraveled. What appeared as arbitrage brilliance—exploiting crypto price disparities between U.S. and Japanese markets—was, in reality, an elaborate shell game. Alameda’s dependence on FTT as collateral created a feedback loop of circular credit. When suspicion triggered a run on FTX, the illusion of stability collapsed under the weight of its own contradictions.
#
# At its core, FTX’s story is a parable of the Red Queen’s race: a relentless pursuit of dominance in an ecosystem designed for fragility. Bankman-Fried’s self-styling as crypto’s J.P. Morgan—a savior amid market turmoil—masked the monopoly delusion that ultimately doomed his venture. The empire’s Achilles’ heel was its reliance on trust tokens conjured from thin air, a precarious system that succumbed to the very entropy it claimed to tame.
#
# This tale of tokens, resources, and odds encapsulates the inherent contradictions of cryptocurrency. Bitcoin, with its promise of fixed odds and transparency, represents a coin toss where rules are immutable. FTX, by contrast, thrived on a roulette of engineered volatility, where the house always won—until it didn’t. The collapse of FTX underscores the difference between systems built on trust and those designed to manufacture it. The former thrives on clarity; the latter on illusion.
#
# FTX’s fall reveals broader truths about optimization and entropy in the digital age. It is a cautionary tale about the dangers of weaponized trust and the fragility of systems built on opacity. Bankman-Fried, once hailed as a savior, became the architect of his own undoing. His refusal to pivot into survival mode, his monopolization of access to “keys,” and his hubris in perpetuating a collapsing system reflect a Victorian morality play as much as a Coen Brothers farce.
#
# The collapse of FTX isn’t merely a crypto scandal—it’s a meditation on the aesthetic of collapse itself. Goethe’s axiom about the artist and moral purpose applies here: to demand optimization from a system designed for volatility is to ruin it. Bankman-Fried’s attempt to impose order on chaos unraveled its delicate artifice. The Victorian within us craves a moral to this story, while the Coen Brothers would likely settle for a sardonic shrug. Perhaps the truth lies somewhere in between—a tale of tokens and trust, hubris and entropy, and the inevitable gravitational pull of collapse masquerading as progress.

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# Define the neural network fractal
def define_layers():
    return {
        'World': ['Cosmos-Entropy', 'Planet-Tempered', 'Life-Needs', 'Ecosystem-Costs', 'Generative-Means', 'Cartel-Ends', ], ## Cosmos, Planet
        'Perception': ['Perception-Ledger'], # Life
        'Agency': ['Open-Nomiddleman', 'Closed-Trusted'], # Ecosystem (Beyond Principal-Agent-Other)
        'Generative': ['Ratio-Weaponized', 'Competition-Tokenized', 'Odds-Monopolized'], # Generative
        'Physical': ['Volatile-Distributed', 'Unknown-Players',  'Freedom-Crypto', 'Known-Transactions', 'Stable-Central'] # Physical
    }

# Assign colors to nodes
def assign_colors():
    color_map = {
        'yellow': ['Perception-Ledger'],
        'paleturquoise': ['Cartel-Ends', 'Closed-Trusted', 'Odds-Monopolized', 'Stable-Central'],
        'lightgreen': ['Generative-Means', 'Competition-Tokenized', 'Known-Transactions', 'Freedom-Crypto', 'Unknown-Players'],
        'lightsalmon': [
            'Life-Needs', 'Ecosystem-Costs', 'Open-Nomiddleman', # Ecosystem = Red Queen = Prometheus = Sacrifice
            'Ratio-Weaponized', 'Volatile-Distributed'
        ],
    }
    return {node: color for color, nodes in color_map.items() for node in nodes}

# Calculate positions for nodes
def calculate_positions(layer, x_offset):
    y_positions = np.linspace(-len(layer) / 2, len(layer) / 2, len(layer))
    return [(x_offset, y) for y in y_positions]

# Create and visualize the neural network graph
def visualize_nn():
    layers = define_layers()
    colors = assign_colors()
    G = nx.DiGraph()
    pos = {}
    node_colors = []

    # Add nodes and assign positions
    for i, (layer_name, nodes) in enumerate(layers.items()):
        positions = calculate_positions(nodes, x_offset=i * 2)
        for node, position in zip(nodes, positions):
            G.add_node(node, layer=layer_name)
            pos[node] = position
            node_colors.append(colors.get(node, 'lightgray'))  # Default color fallback

    # Add edges (automated for consecutive layers)
    layer_names = list(layers.keys())
    for i in range(len(layer_names) - 1):
        source_layer, target_layer = layer_names[i], layer_names[i + 1]
        for source in layers[source_layer]:
            for target in layers[target_layer]:
                G.add_edge(source, target)

    # Draw the graph
    plt.figure(figsize=(12, 8))
    nx.draw(
        G, pos, with_labels=True, node_color=node_colors, edge_color='gray',
        node_size=3000, font_size=9, connectionstyle="arc3,rad=0.2"
    )
    plt.title("World, Money, Bank, Exchange, Yield", fontsize=15)
    plt.show()

# Run the visualization
visualize_nn()

# %% [markdown]
# ```{figure} ../../figures/blanche.*
# ---
# width: 1
# height: 1
# ---
# _Terra, Celsius, FTX_. Contemplate the following: world (twitter), money (terra), bank (celsius), exchange (ftx), yields (hedgefunds). IT’S A REALLY, surprisingly user-friendly experience,” says Stephen Askins, a shipping lawyer, of his interactions with the Houthis, the militia that has been attacking commercial ships in the Red Sea for more than a year. “You write to them, respectfully. They write back, respectfully, and wish you a happy passage.” Source: [Economist](https://www.economist.com/interactive/international/2025/01/18/inside-the-houthis-moneymaking-machine)
# ```
#
# <Details>
#     <Summary></Summary>
#
# 1. Entropy, Gravity: Founded in Berkeley & setup in Hongkong -> Bahamas -> US?
#    - Gate: everyone is within the gates, perfect information, fixed odds
#    - Coin toss, Dice roll, Roulette spin, Bespoke regulation?
# 2. Patterns: Obsessed with risk, solving puzzles, Maths from MIT
#    - Key: only you are in and others speculate, asymmetric information, wild odds
#    - Poker, Blockchain, Untrusted (Sam Blankman-Fried "sold" trust instead of openness)?
# 3. Connotation: Got kapital from family & later market
#    - Entrants: with their exits and entrances, uncertain odds
#    - Horse racing, DC regulation would give access to Wallstreet?
# 4. Interaction: US-Japan arbitrage on crypto pricing
#    - Stable-Diffusion: weaponized, tokenized, monopolized access-to-key, conditional odds
#    - Red Queen, Exchanges, FTX (nested within Alameda; same people; monopoly-delusion)
# 5. Tendency: Innocuous name: Alameda Research vs. FTX
#    - Optimization: volatility, uncertainty, freedom, certainty, stability
#    - Victorian vs. Coen Brothers, Morality vs. Aesthetics, Teleology vs. Eternal Return
#
# odds ~ resources ~ tokens
#
# - Fixed for Bitcoin
# - Out of thinair for FTX
# - Alameda borrows from FTX with FTT as collateral (when lenders test the waters out of suspicion)
# - Then Sam Bankman-Fried becomes JP-Morgan of crypto
#    - Crypto-bro of last resort
#    - Bailing out the ecosystem
#    - Instead of going into survival mode
#
#
# “TO DEMAND moral purpose from the artist is to make him ruin his work,” said Goethe. Once, I would have defended that statement as if it were an article of religion. Now, having reached the end of my own brief memoir, I find the Victorian in me will not be satisfied without a moral—or perhaps, it is fairer to say, a conclusion. And since I am writing this to please no one but myself, a conclusion is what I will damn well write.”
#
# Excerpt From
# The Various Flavors of Coffee
# Anthony Capella
# https://books.apple.com/us/book/the-various-flavors-of-coffee/id420768595
# This material may be protected by copyright.
#
# Layers/colors:
#
# 1. Grey/Cambridge: Aesthetic (100%)
# 2. Yellow/Wallstreet: Instant Gratification
# 3. Salmon/BayArea: Bracing for Worthy-Adversary
# 4. Paleturquoise/Oxford: Secured Cartel (Might makes right)
# 5. Lightgreen/LSE: Optimization, Morality, Teleology (5%-95%)
#
# </Details>
